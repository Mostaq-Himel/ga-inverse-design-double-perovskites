# %% [markdown]
# Step 2: ML

# %%
import joblib
import pandas as pd
import os

# Load ML-ready data
# X
features_directory = "../data"
features_filename = "dp_magpie_features.pkl"
features_path = os.path.join(features_directory, features_filename)

X = joblib.load(features_path)

# y
targets_directory = "../data"
targets_filename = "dp_bandgap_targets.pkl"
targets_path= os.path.join(targets_directory, targets_filename)

y = joblib.load(targets_path)

print("Feature matrix shape:", X.shape)
print("Target vector length:", len(y))
# Out:
# Feature matrix shape: (574, 134)
# Target vector length: 574

# %%
# Drop non-feature / non-numeric columns
non_feature_cols = [
    "material_id",
    "formula_pretty",
    "structure",
    "composition",
    "band_gap",
    "fields_not_requested"
]

X_numeric = X.drop(columns=[c for c in non_feature_cols if c in X.columns])

print("Numeric features shape:", X_numeric.shape)

pd.DataFrame(X_numeric).head()
# Out:
# Numeric features shape: (574, 133)
#    energy_above_hull  MagpieData minimum Number  MagpieData maximum Number  \
# 0           0.004554                        8.0                       56.0
# 1           0.017182                        8.0                       40.0
# 2           0.005751                        8.0                       41.0
# 3           0.006747                        8.0                       73.0
# 4           0.005610                        8.0                       83.0
#
#    MagpieData range Number  MagpieData mean Number  MagpieData avg_dev Number  \
# 0                     48.0                    22.6                      17.52
# 1                     32.0                    18.7                      12.84
# 2                     33.0                    19.0                      13.20
# 3                     65.0                    25.8                      21.52
# 4                     75.0                    17.8                      14.08
#
#    MagpieData mode Number  MagpieData minimum MendeleevNumber  \
# 0                     8.0                                 9.0
# 1                     8.0                                 8.0
# 2                     8.0                                 8.0
# 3                     8.0                                 9.0
# 4                     8.0                                46.0
#
#    MagpieData maximum MendeleevNumber  MagpieData range MendeleevNumber  ...  \
# 0                                87.0                              78.0  ...
# 1                                87.0                              79.0  ...
# 2                                87.0                              79.0  ...
# 3                                87.0                              78.0  ...
# 4                                87.0                              41.0  ...
#
#    MagpieData range GSmagmom  MagpieData mean GSmagmom  \
# 0                    0.00031                  0.000031
# 1                    0.00000                  0.000000
# 2                    0.00031                  0.000031
# 3                    0.00031                  0.000031
# 4                    0.00000                  0.000000
#
#    MagpieData avg_dev GSmagmom  MagpieData mode GSmagmom  \
# 0                     0.000056                       0.0
# 1                     0.000000                       0.0
# 2                     0.000056                       0.0
# 3                     0.000056                       0.0
# 4                     0.000000                       0.0
#
#    MagpieData minimum SpaceGroupNumber  MagpieData maximum SpaceGroupNumber  \
# 0                                 12.0                                229.0
# 1                                 12.0                                229.0
# 2                                 12.0                                229.0
# 3                                 12.0                                229.0
# 4                                 12.0                                229.0
#
#    MagpieData range SpaceGroupNumber  MagpieData mean SpaceGroupNumber  \
# 0                              217.0                              97.6
# 1                              217.0                              94.5
# 2                              217.0                              96.8
# 3                              217.0                              97.6
# 4                              217.0                              70.1
#
#    MagpieData avg_dev SpaceGroupNumber  MagpieData mode SpaceGroupNumber
# 0                               102.72                              12.0
# 1                                99.00                              12.0
# 2                               101.76                              12.0
# 3                               102.72                              12.0
# 4                                81.34                              12.0
#
# [5 rows x 133 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_numeric,
    y,
    test_size=0.2,
    random_state=42
)


print("Train samples:", len(X_train))
print("Test samples:", len(X_test))
# Out:
# Train samples: 459
# Test samples: 115

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
print("Random Forest training completed!")
# Out:
# Random Forest training completed!

# %%
# Evaluate model performance
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Predict on test set
y_pred = rf.predict(X_test)

# Metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.3f} eV")
print(f"R² score: {r2:.3f}")

# Optional: scatter plot
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([0,5],[0,5], "k--", lw=2)
plt.xlabel("DFT Band Gap (eV)")
plt.ylabel("Predicted Band Gap (eV)")
plt.title("Random Forest Band Gap Prediction")
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 0.401 eV
# R² score: 0.750

# %%
# Feature importance
import numpy as np

importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Top 10 features
for i in range(10):
    print(f"{X.columns[indices[i]]}: {importances[indices[i]]:.4f}")
# Out:
# MagpieData range Column: 0.1146
# MagpieData range SpaceGroupNumber: 0.0588
# MagpieData mean Column: 0.0570
# MagpieData maximum NValence: 0.0437
# MagpieData mean Electronegativity: 0.0381
# MagpieData mean NdValence: 0.0372
# MagpieData mean GSmagmom: 0.0355
# MagpieData mean NValence: 0.0289
# MagpieData range MeltingT: 0.0270
# MagpieData mean MeltingT: 0.0268

# %%
# Save model for GA
joblib.dump(rf, "rf_bandgap_dp.pkl")
print("Random Forest model saved as rf_bandgap_dp.pkl")
# Out:
# Random Forest model saved as rf_bandgap_dp.pkl
